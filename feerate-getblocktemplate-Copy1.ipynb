# %%
import pandas as pd
import numpy as np
import jsonrpc_requests as jrpc
import wtfutil
import time
import pyarrow.parquet as pq
import pathlib

# %%
bitcoind = jrpc.Server('http://user:pass@172.17.0.3:8332')

def load_last_pq(suffix='full', count=1):
    folder = pathlib.Path('data/2017/11/16/')
    folder.glob(f'*_{suffix}.parq')
    
    filebasenames = []
    
    


load_last_pq()
#pq.read_pandas('data/2017/11/16/')
#gb['tx_count'] = len(gb['tx'])
#del gb['tx']
#gb

#time.time() - gb['time']

# %%
df_gbt = wtfutil.prepare_gbt(bitcoind.getblocktemplate())
df_gbt.describe()
#pd.qcut(df_gbt.vsize, 10)
df_gbt.reset_index().drop('index', 1)
# Out:
#       vsize  satoshi     feerate  position  is_leaf  is_woven  has_witness
# 0       226     7910   35.000000       983     True     False        False
# 1       374    41514  111.000000       509    False      True        False
# 2       226     8136   36.000000       472     True     False        False
# 3       226     8362   37.000000       324     True     False        False
# 4      1406    50000   35.561878       533     True     False        False
# 5       224     7684   34.303571      1269     True     False        False
# 6       226      678    3.000000       909     True      True        False
# 7       225     8362   37.164444       446    False      True        False
# 8       226     8362   37.000000       329     True     False        False
# 9       484    16704   34.512397      1186     True     False        False
# 10      225     7910   35.155556       876     True     False        False
# ...

# %%
df_gbt = wtfutil.prepare_gbt(bitcoind.getblocktemplate())
agg_gbt = wtfutil.aggregate_mempool(df_gbt, 20)
out = wtfutil.calculate_rcs(agg_gbt)
out = wtfutil.annotate_feerate(out)
out.style.bar()
# Out:
# <style  type="text/css" >
#     #T_93a22254_cb0d_11e7_8d36_0242ac110005row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.2%, transparent 0%);
#         }    #T_93a22254_cb0d_11e7_8d36_0242ac110005row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0%);
#         }    #T_93a22254_cb0d_11e7_8d36_0242ac110005row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_93a22254_cb0d_11e7_8d36_0242ac110005row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_93a22254_cb0d_11e7_8d36_0242ac110005row0_col4 {
#             width:  10em;
#              height:  80%;
# ...

# %%
# Out:
# 'feerate_lfb60'

# %%
an
# Out:
#                  cnt       mvs       btc
# feerate_lfb60
# 0                0.0  0.000000  0.000000
# 1                0.0  0.000000  0.000000
# 2                0.0  0.000000  0.000000
# 3                0.0  0.000000  0.000000
# 4                0.0  0.000000  0.000000
# 5                0.0  0.000000  0.000000
# 6                0.0  0.000000  0.000000
# 7                0.0  0.000000  0.000000
# 8                0.0  0.000000  0.000000
# 9                0.0  0.000000  0.000000
# 10               0.0  0.000000  0.000000
# 11               1.0  0.000224  0.000013
# 12               0.0  0.000000  0.000000
# 13               0.0  0.000000  0.000000
# 14               0.0  0.000000  0.000000
# 15               0.0  0.000000  0.000000
# 16               0.0  0.000000  0.000000
# 17               0.0  0.000000  0.000000
# 18               0.0  0.000000  0.000000
# 19               0.0  0.000000  0.000000
# 20               1.0  0.000258  0.000068
# ...
