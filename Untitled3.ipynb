# %%
import jsonrpc_requests
import pandas as pd


b = jsonrpc_requests.Server('http://user:pass@172.17.0.7:8332')

# %%
df0 = pd.read_csv('Extranonce-analysis2009.csv')

# %%
df = df0.copy()

# %%
df.columns=['h', 'dalloc', 'walloc', 'nalloc']

# %%
df = df.assign(utxo=sutxo)

# %%
df = df[0:36287]

# %%
df.query('dalloc == dalloc and utxo == False')
# Out:
#            h dalloc walloc nalloc   utxo
# 9          9     52    NaN    NaN  False
# 78        78     15    NaN    NaN  False
# 286      286     51    NaN    NaN  False
# 688      688    152    NaN    NaN  False
# 726      726     56    NaN    NaN  False
# 877      877    798    NaN    NaN  False
# 1408    1408     25    NaN    NaN  False
# 1760    1760    953    NaN    NaN  False
# 1917    1917      1    NaN    NaN  False
# 1918    1918      2    NaN    NaN  False
# 1920    1920      4    NaN    NaN  False
# 2108    2108    936    NaN    NaN  False
# 2116    2116    944    NaN    NaN  False
# 2197    2197     88    NaN    NaN  False
# 2459    2459    160    NaN    NaN  False
# 2485    2485    238    NaN    NaN  False
# 2575    2575    649    NaN    NaN  False
# 2577    2577    651    NaN    NaN  False
# 2825    2825   1670    NaN    NaN  False
# 3416    3416   1512    NaN    NaN  False
# 3479    3479   1716    NaN    NaN  False
# 3909    3909    733    NaN    NaN  False
# ...

# %%
a = len(df.query('dalloc == dalloc and utxo == True'))
b = len(df.query('dalloc == dalloc and utxo == False'))
print (a, b, b/(a+b))
# Out:
# 14742 73 0.004927438407019912

# %%
df.query('walloc == walloc and utxo == False')
# Out:
#            h dalloc walloc nalloc   utxo
# 20448  20448    NaN     18    NaN  False
# 21439  21439    NaN     21    NaN  False
# 21440  21440    NaN     23    NaN  False
# 21441  21441    NaN     24    NaN  False
# 21442  21442    NaN     26    NaN  False
# 21443  21443    NaN     27    NaN  False
# 21444  21444    NaN     29    NaN  False
# 21445  21445    NaN     30    NaN  False
# 21446  21446    NaN     32    NaN  False
# 21447  21447    NaN     33    NaN  False
# 21448  21448    NaN     34    NaN  False
# 21451  21451    NaN     38    NaN  False
# 21459  21459    NaN     47    NaN  False
# 21460  21460    NaN     48    NaN  False
# 21461  21461    NaN     49    NaN  False
# 21462  21462    NaN     51    NaN  False
# 21463  21463    NaN     53    NaN  False
# 21464  21464    NaN     55    NaN  False
# 21465  21465    NaN     56    NaN  False
# 21466  21466    NaN     58    NaN  False
# 21470  21470    NaN     62    NaN  False
# 21877  21877    NaN    340    NaN  False
# ...

# %%
a = len(df.query('walloc == walloc and utxo == True'))
b = len(df.query('walloc == walloc and utxo == False'))
print (a, b, b/(a+b))
# Out:
# 4443 110 0.024159894575005492

# %%
a = len(df.query('nalloc == nalloc and utxo == True'))
b = len(df.query('nalloc == nalloc and utxo == False'))
print (a, b, b/(a+b))
# Out:
# 3302 13617 0.8048348011111768

# %%
len(df.query('walloc == walloc and utxo == True'))
# Out:
# 4443

# %%
len(df.query('walloc == walloc and utxo == False'))
# Out:
# 110

# %%
len(df.query('nalloc == nalloc and utxo == True'))
# Out:
# 3302

# %%
len(df.query('nalloc == nalloc and utxo == False'))
# Out:
# 13617

# %%
pd.Series([b.gettxout(b.getblock(b.getblockhash(i))['tx'][0], 0) != None for i in range(36287)])
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9        False
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 36257    False
# 36258    False
# 36259    False
# 36260     True
# 36261    False
# 36262     True
# 36263    False
# 36264     True
# 36265    False
# 36266    False
# 36267    False
# 36268    False
# 36269    False
# 36270    False
# 36271    False
# 36272    False
# 36273     True
# 36274    False
# 36275     True
# 36276    False
# 36277    False
# 36278    False
# 36279    False
# 36280    False
# 36281    False
# 36282    False
# 36283     True
# ...

# %%
sutxo = _
