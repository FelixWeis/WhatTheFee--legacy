# %%
import pandas as pd
import numpy as np
import jsonrpc_requests as jrpc
import wtfutil
import time
import pathlib
import datetime

arcs = wtfutil.annotate_rcs
afr = wtfutil.annotate_feerate

# %%
FEEAGG_BUCKETS=60
PATH_PREFIX=datetime.datetime.utcnow().strftime('data/%Y/%m/%d/')
DELTA_DATAPOINTS=120 # 40 dp * 15 sec/dp = 600
COLORS=['#8cff66', '#ff668c', '#668cff']

bitcoind = jrpc.Server('http://user:pass@172.17.0.3:8332')

txpool_delta = pd.concat(wtfutil.pqload_lastn(PATH_PREFIX, 'diff', DELTA_DATAPOINTS))
feeagg_delta = wtfutil.feeagg(txpool_delta, FEEAGG_BUCKETS) * 40 / DELTA_DATAPOINTS

txpool_gbtpl = wtfutil.txpool_from_getblocktemplate(bitcoind.getblocktemplate())
feeagg_gbtpl = wtfutil.feeagg(txpool_gbtpl, FEEAGG_BUCKETS)

txpool_mpool = pd.concat(wtfutil.pqload_lastn(PATH_PREFIX, 'full', 1).values())
feeagg_mpool = wtfutil.feeagg(txpool_mpool, FEEAGG_BUCKETS)

since_last_block = time.time() - bitcoind.getblockheader(bitcoind.getblockchaininfo()['bestblockhash'])['time']

print(since_last_block)
# Out:
# 255.69847130775452

# %%
afr(arcs(feeagg_delta)).style.bar(width=100, color=COLORS[0], align='zero')
# Out:
# <style  type="text/css" >
#     #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 100.0%, transparent 100.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #8cff66 50%, #8cff66 50.0%, transparent 50.0%);
#         }    #T_1d6e2c06_f6da_11e7_ac06_0242ac110005row4_col0 {
#             width:  10e

# %%
afr(arcs(feeagg_gbtpl)).style.bar(width=100, color=COLORS[1], align='zero')
# Out:
# <style  type="text/css" >
#     #T_1d77123a_f6da_11e7_ac06_0242ac110005row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 100.0%, transparent 100.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #ff668c 50%, #ff668c 50.0%, transparent 50.0%);
#         }    #T_1d77123a_f6da_11e7_ac06_0242ac110005row4_col0 {
#             width:  10e

# %%
afr(arcs(feeagg_mpool)).style.bar(width=100, color=COLORS[2], align='zero')
# Out:
# <style  type="text/css" >
#     #T_1d804800_f6da_11e7_ac06_0242ac110005row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_1d804800_f6da_11e7_ac06_0242ac110005row4_col0 {
#             width:  10e

# %%
a,b,c = [feeagg_delta.copy(), feeagg_mpool.copy(),feeagg_gbtpl.copy()]
a.index = pd.Index(range(FEEAGG_BUCKETS)).astype(str).map(lambda x: x.zfill(2)) + '+'
b.index = pd.Index(range(FEEAGG_BUCKETS)).astype(str).map(lambda x: x.zfill(2)) + '='
c.index = pd.Index(range(FEEAGG_BUCKETS)).astype(str).map(lambda x: x.zfill(2)) + '-'

def high3(s):
    bar_sz = np.round(s/s.max()*100,2)
    colors=['#8cff66', '#ff668c', '#668cff']

    return [f'background: linear-gradient(90deg,{colors[i%3]} {v}%, transparent 0%)' 
            for i, v in enumerate(bar_sz)]

def high2(s):
    bar_sz = np.round(s/s.max()*100,2)
    colors=['#8cff66', '#ff668c']

    return [f'background: linear-gradient(90deg,{colors[i%2]} {v}%, transparent 0%)' 
            for i, v in enumerate(bar_sz)]


def nop(s):
    pass

out3 = pd.concat([arcs(a), arcs(b), arcs(c)])
out3.sort_index()\
    .style.bar() \
    .apply(high3)\
    .format({'mvs': '{:.3f}', 'btc': '{:.6f}'}) \
    .set_properties(**{'max-width': '100%', 'font-family': 'monospace'}) \
    .set_table_styles([dict(selector="th", props=[("font-family", "monospace")])])
# Out:
# <style  type="text/css" >
#     #T_1e4a514a_f6da_11e7_ac06_0242ac110005 th {
#           font-family: monospace;
#     }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.3%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 7.35%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.4%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 3.44%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.2%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 1.24%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.6%, transparent 0%);
#             background:  linear-gradient(90deg,#ff668c 5.65%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 0%);
#             background:  linear-gradient(90deg,#ff668c 2.39%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#             background:  linear-gradient(90deg,#ff668c 0.74%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#             background:  linear-gradient(90deg,#668cff 100.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#             background:  linear-gradient(90deg,#668cff 100.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#             background:  linear-gradient(90deg,#668cff 100.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.3%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 7.35%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.4%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 3.44%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.2%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 1.24%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1e4a514a_f6da_11e7_ac06_0242ac110005row4_col2 {
#             width:  10em;
#              height:  80%;

# %%
out2 = pd.concat([arcs(a), arcs(c)])
out2.sort_index()\
    .style.bar() \
    .apply(high2)\
    .format({'mvs': '{:.3f}', 'btc': '{:.6f}'}) \
    .set_properties(**{'max-width': '100%', 'font-family': 'monospace'}) \
    .set_table_styles([dict(selector="th", props=[("font-family", "monospace")])])
# Out:
# <style  type="text/css" >
#     #T_1eca8338_f6da_11e7_ac06_0242ac110005 th {
#           font-family: monospace;
#     }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 100.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 100.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 100.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 76.8%, transparent 0%);
#             background:  linear-gradient(90deg,#ff668c 76.82%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 69.6%, transparent 0%);
#             background:  linear-gradient(90deg,#ff668c 69.58%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.8%, transparent 0%);
#             background:  linear-gradient(90deg,#ff668c 59.78%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 100.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 100.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#             background:  linear-gradient(90deg,#8cff66 100.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff668c 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 76.8%, transparent 0%);
#             background:  linear-gradient(90deg,#ff668c 76.82%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 69.6%, transparent 0%);
#             background:  linear-gradient(90deg,#ff668c 69.58%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.8%, transparent 0%);
#             background:  linear-gradient(90deg,#ff668c 59.78%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#8cff66 0.0%, transparent 0%);
#             max-width:  100%;
#             font-family:  monospace;
#         }    #T_1eca8338_f6da_11e7_ac06_0242ac110005row4_col2 {
#             width:  10em;
#              he

# %%
import matplotlib.pyplot as plt
def plot_p100(agg_in, legend=True, title=None):
    agg=agg_in.copy().drop('cnt', 1)
    
    
    p100 = agg.div(agg.sum(0), axis=1) * 100
    p100.index = np.round(np.exp(np.arange(FEEAGG_BUCKETS) / FEEAGG_BUCKETS * 10),1)
    p100.columns = p100.columns.astype(str) + '=' + np.round(agg.sum(0),3).astype(str) #pd.Index(['a', 'b', 'c'])
    
    fig = plt.figure(figsize=(6,2), dpi=160)
    ax = plt.subplot(111)

    p100.T.plot(kind='barh', stacked=True, ax=ax, colormap='cubehelix', legend=False, title=title)
    ax.xaxis.grid(color='gray', linestyle='dashed')

    box = ax.get_position()
    ax.set_position([box.x0, box.y0 + box.height * 0.01,
                     box.width, box.height * 0.5])
    if legend:        
        ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),
                  fancybox=True, shadow=False, ncol=5)


plot_p100(feeagg_mpool, False, title='Mempool')
plot_p100(feeagg_delta, False, title='Delta10m')
plot_p100(feeagg_gbtpl, True, title='Blocktemplate')

plt.show()

# %% [markdown]
# ## Pump the mempool

# %%
feeagg_mp72 = feeagg_mpool -  wtfutil.mine_efficiently(feeagg_mpool, 72)
plot_p100(feeagg_mp72, True, title='Mempool72')

plt.show()

# %% [markdown]
# ## Drain the mempool

# %%
m1 = wtfutil.mine_efficiently(feeagg_mpool, mvs=1.0)
m4 = wtfutil.mine_efficiently(feeagg_mpool, mvs=4.0)
m16 = wtfutil.mine_efficiently(feeagg_mpool, mvs=16.0)

plot_p100(m1, False, title='Mempool-1MV')
plot_p100(m4, False, title='Mempool-4MV')
plot_p100(m16, False, title='Mempool-16MV')

plt.show()

# %%
# how does GBT looks like in those simulations
plot_p100(feeagg_mpool - m1, False, title='Blocktemplate-1MV')
plot_p100(feeagg_mpool - m4, False, title='Blocktemplate-4MV')
plot_p100(feeagg_mpool - m16, False, title='Blocktemplate-16MV')
plt.show()

# %%
# Simulation 2

# %%
PREMINE = 0.0
feeagg_sim_start = wtfutil.mine_efficiently(feeagg_mpool, mvs=PREMINE)

plot_p100(feeagg_sim_start , False, title='sim start')
plt.show()

# %%
# simulation 1: 3 blocks in 30 minutes



steps = wtfutil.simulate_simple(feeagg_sim_start, feeagg_delta, nmeans=12, nblocks=12, mvs=1.0)

for i, s in enumerate(steps):
    if i % 2 == 0: 
        plot_p100(s[0] , False, title=f'SIM: feeagg_gbtpl blk {i+1}')

plt.show()

# %%
for i, s in enumerate(steps):
    if i % 2 == 0: 
        plot_p100(s[1] , False, title=f'SIM: feeagg_mpool blk {i+1}')

plt.show()

# %%
feeagg_post_sim = steps[-1][1]
afr(arcs(feeagg_post_sim)).style.bar(width=100, color=COLORS[2], align='zero')
# Out:
# <style  type="text/css" >
#     #T_4a69851c_d48d_11e7_a7e9_0242ac110005row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 79.6%, transparent 79.6%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 51.4%, transparent 51.4%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 58.5%, transparent 58.5%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.9%, transparent 50.9%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 77.1%, transparent 77.1%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 95.1%, transparent 95.1%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 99.4%, transparent 99.4%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 90.9%, transparent 90.9%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 52.3%, transparent 52.3%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 51.2%, transparent 51.2%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 81.6%, transparent 81.6%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 93.7%, transparent 93.7%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 99.0%, transparent 99.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 86.0%, transparent 86.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 53.2%, transparent 53.2%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.5%, transparent 50.5%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 61.7%, transparent 61.7%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 93.4%, transparent 93.4%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 98.5%, transparent 98.5%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 80.3%, transparent 80.3%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_4a69851c_d48d_11e7_a7e9_0242ac110005row4_col0 {
#             width:  10em;

# %%
mvs = feeagg_post_sim['mvs']

# %%
def lowest_mined(df):
    retval = len(df['mvs'][::-1])
    for i, val in df['mvs'][::-1].iteritems():
        if val != 0:
            return retval
        retval = i
    return retval

lowest_mined(feeagg_post_sim)
# Out:
# 29

# %%
results1= {6: {'0.1974': 8,
  '0.2611': 7,
  '0.3829': 7,
  '0.5000': 6,
  '0.6827': 5,
  '0.9545': 2,
  '0.9973': 1,
  '0.9999': 0},
 9: {'0.1974': 11,
  '0.2611': 11,
  '0.3829': 10,
  '0.5000': 9,
  '0.6827': 7,
  '0.9545': 4,
  '0.9973': 2,
  '0.9999': 0},
 12: {'0.1974': 15,
  '0.2611': 14,
  '0.3829': 13,
  '0.5000': 12,
  '0.6827': 10,
  '0.9545': 7,
  '0.9973': 4,
  '0.9999': 1},
 18: {'0.1974': 22,
  '0.2611': 21,
  '0.3829': 19,
  '0.5000': 18,
  '0.6827': 16,
  '0.9545': 11,
  '0.9973': 7,
  '0.9999': 4},
 24: {'0.1974': 28,
  '0.2611': 27,
  '0.3829': 25,
  '0.5000': 24,
  '0.6827': 22,
  '0.9545': 16,
  '0.9973': 12,
  '0.9999': 8},
 36: {'0.1974': 41,
  '0.2611': 40,
  '0.3829': 38,
  '0.5000': 36,
  '0.6827': 33,
  '0.9545': 26,
  '0.9973': 21,
  '0.9999': 16},
 48: {'0.1974': 54,
  '0.2611': 52,
  '0.3829': 50,
  '0.5000': 48,
  '0.6827': 45,
  '0.9545': 37,
  '0.9973': 30,
  '0.9999': 24},
 72: {'0.1974': 79,
  '0.2611': 77,
  '0.3829': 74,
  '0.5000': 72,
  '0.6827': 68,
  '0.9545': 58,
  '0.9973': 50,
  '0.9999': 42},
 96: {'0.1974': 104,
  '0.2611': 102,
  '0.3829': 99,
  '0.5000': 96,
  '0.6827': 91,
  '0.9545': 80,
  '0.9973': 70,
  '0.9999': 61},
 144: {'0.1974': 154,
  '0.2611': 152,
  '0.3829': 147,
  '0.5000': 144,
  '0.6827': 138,
  '0.9545': 124,
  '0.9973': 112,
  '0.9999': 101}}

# %%
#%%time
def simulate_all(fa_start, fa_delta):
    results2 = {}
    for nmean, probs in results1.items():
        results2[nmean] = dict()
        for p, nblocks in probs.items():
            if nblocks == 0:
                results2[nmean][p] = None
            else:
                steps = wtfutil.simulate_simple(fa_start, fa_delta, nmeans=nmean, nblocks=nblocks, mvs=1.0)
                feeagg_post_sim = steps[-1][1]
                results2[nmean][p] = lowest_mined(feeagg_post_sim)
    return results2


r = pd.DataFrame.from_dict(simulate_all(feeagg_sim_start, feeagg_delta *.5), orient='index')
r
# Out:
#      0.1974  0.2611  0.3829  0.5000  0.6827  0.9545  0.9973  0.9999
# 6        29      29      29      29      29      31      32     NaN
# 9        28      28      29      29      29      30      32     NaN
# 12       25      26      27      28      29      29      31    32.0
# 18       22      23      24      25      27      29      31    32.0
# 24       20      21      22      23      24      29      29    31.0
# 36       15      16      17      19      21      26      29    30.0
# 48       11      12      14      15      17      23      28    29.0
# 72        8       8       9      10      11      17      22    28.0
# 96        4       4       5       6       8      12      17    23.0
# 144       1       1       2       2       3       5       9    14.0

# %%
np.round(np.exp(r/FEEAGG_BUCKETS*10),1)
# Out:
#      0.1974  0.2611  0.3829  0.5000  0.6827  0.9545  0.9973  0.9999
# 6     125.6   125.6   125.6   125.6   125.6   175.3   207.1     NaN
# 9     106.3   106.3   125.6   125.6   125.6   148.4   207.1     NaN
# 12     64.5    76.2    90.0   106.3   125.6   125.6   175.3   207.1
# 18     39.1    46.2    54.6    64.5    90.0   125.6   175.3   207.1
# 24     28.0    33.1    39.1    46.2    54.6   125.6   125.6   175.3
# 36     12.2    14.4    17.0    23.7    33.1    76.2   125.6   148.4
# 48      6.3     7.4    10.3    12.2    17.0    46.2   106.3   125.6
# 72      3.8     3.8     4.5     5.3     6.3    17.0    39.1   106.3
# 96      1.9     1.9     2.3     2.7     3.8     7.4    17.0    46.2
# 144     1.2     1.2     1.4     1.4     1.6     2.3     4.5    10.3
