# %%
import pandas as pd
import numpy as np
import jsonrpc_requests as jrpc
import wtfutil
import time
import pathlib

rcs = wtfutil.calculate_rcs
ann = wtfutil.annotate_feerate

# %%
BUCKETS=20
PATH_PREFIX=datetime.datetime.utcnow().strftime('data/%Y/%m/%d/')
#FILE_SUFFIX='blocktemplate'
DATAPOINTS=1


bitcoind = jrpc.Server('http://user:pass@172.17.0.3:8332')

blocktemplate = bitcoind.getblocktemplate()
txpool = wtfutil.prepare_getblocktemplate(blocktemplate)
agg_gbt = wtfutil.aggregate_mempool(txpool, BUCKETS)
#agg_gbt = agg_delta * -1

ann(rcs(agg_gbt * -1)).style.bar(width=100, color='#668cff', align='zero')
# Out:
# <style  type="text/css" >
#     #T_929e1c8c_cf04_11e7_961e_0242ac110005row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #668cff 0.0%, #668cff 50%, transparent 50%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_929e1c8c_cf04_11e7_961e_0242ac110005row4_col0 {
#             width:  10em;
#              height:  80%;
#             backgr

# %%
txpool = wtfutil.prepare_getblocktemplate(bitcoind.getblocktemplate())
txpool.describe()
# Out:
#               vsize       satoshi      feerate     position
# count   2437.000000  2.437000e+03  2437.000000  2437.000000
# mean     409.495691  4.968419e+04   112.727557  1218.000000
# std     1071.481099  3.763545e+05   144.545780   703.645626
# min      189.000000  2.440000e+02     1.270833     0.000000
# 25%      225.000000  1.095000e+04    42.473054   609.000000
# 50%      226.000000  1.814400e+04    72.320000  1218.000000
# 75%      339.000000  3.682900e+04   149.173653  1827.000000
# max    29871.000000  1.758170e+07  1773.685864  2436.000000

# %%
df_gbt = wtfutil.prepare_getblocktemplate(bitcoind.getblocktemplate())
agg_gbt = wtfutil.aggregate_mempool(df_gbt, 20)
out = wtfutil.calculate_rcs(agg_gbt)
out = wtfutil.annotate_feerate(out, btcprice=9000, typical_vsize=225)
out.style.bar(width=50, color='#668cff')
# Out:
# <style  type="text/css" >
#     #T_04cd6c8c_ce14_11e7_961e_0242ac110005row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.1%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row0_col6 {
#             width:  10em;
#              height:  80%;
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row0_col7 {
#             width:  10em;
#              height:  80%;
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row1_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row1_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row1_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.2%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.1%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 1.2%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.1%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.9%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 49.9%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.6%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.4%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 49.6%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 50.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 49.7%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row4_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.0%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.5%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668cff 0.1%, transparent 0%);
#         }    #T_04cd6c8c_ce14_11e7_961e_0242ac110005row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#668

# %%
# time since last block
since_last_block = time.time() - bitcoind.getblockheader(bitcoind.getblockchaininfo()['bestblockhash'])['time']
since_last_block
# Out:
# 254.4501268863678

# %%
import datetime

# %%
# Out:
# datetime.datetime(2017, 11, 19, 0, 31, 42, 819317)

# %%
d = _

# %%
# Out:
# '2017/11/19'
