# %%
import pandas as pd
import numpy as np
import jsonrpc_requests as jrpc
import wtfutil
import time
import pathlib

rcs = wtfutil.calculate_rcs
ann = wtfutil.annotate_feerate

# %%
BUCKETS=20
PATH_PREFIX='data/2017/11/17/'
FILE_SUFFIX='full'
DATAPOINTS=1

bitcoind = jrpc.Server('http://user:pass@172.17.0.3:8332')

tables = wtfutil.pqload_lastn(PATH_PREFIX, FILE_SUFFIX, DATAPOINTS)
txpool = pd.concat(tables.values())
agg_last = wtfutil.aggregate_mempool(txpool, BUCKETS)

ann(rcs(agg_last)).style.bar(width=100, color='#668cff', align='zero')
# Out:
# <style  type="text/css" >
#     #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 81.6%, transparent 81.6%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 53.0%, transparent 53.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 92.5%, transparent 92.5%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 60.7%, transparent 60.7%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 53.2%, transparent 53.2%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 81.4%, transparent 81.4%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 92.7%, transparent 92.7%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 99.0%, transparent 99.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 89.8%, transparent 89.8%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 58.7%, transparent 58.7%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 51.9%, transparent 51.9%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 60.2%, transparent 60.2%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 90.2%, transparent 90.2%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 97.9%, transparent 97.9%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 82.3%, transparent 82.3%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 86.2%, transparent 86.2%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 65.8%, transparent 65.8%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 100.0%, transparent 100.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 88.2%, transparent 88.2%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 97.3%, transparent 97.3%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 79.8%, transparent 79.8%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #668cff 50%, #668cff 50.0%, transparent 50.0%);
#         }    #T_e2bd26fe_cc9d_11e7_96e9_0242ac110005row4_col0 {
#             width:  10em;

# %%
#txpool.quantile(np.arange(1,9)/10).style.bar()
advanced_describe(txpool)
# Out:
#               btc       diff  feerate feerate_lfb20         height is_woven  \
# count        2391       2391     2391          2391    2391.000000      NaN
# mean   0.00160991   0.999164  362.258       11.0577  494674.812631      NaN
# std    0.00616449  0.0409016  227.534       1.90332       0.396669      NaN
# min      2.26e-06         -1        1             0  494671.000000      NaN
# 25%      0.000493          1  173.599            10  494675.000000      NaN
# 50%    0.00103183          1  415.681            12  494675.000000      NaN
# 75%    0.00114627          1   458.68            12  494675.000000      NaN
# max      0.165234          1  2263.16            15  494675.000000      NaN
# 0.1    0.00013559          1       55             8  494674.000000        0
# 0.2      0.000264          1    91.35             9  494675.000000        0
# 0.3      0.000678          1  270.296            11  494675.000000        0
# 0.4    0.00091476          1  371.094            12  494675.000000        0
# 0.5    0.00103183          1  415.681            12  494675.000000        0
# 0.6    0.00103203          1   456.65            12  494675.000000        0
# 0.7    0.00105299          1   458.68            12  494675.000000        0
# 0.8    0.00149818          1  462.704            12  494675.000000        0
# 0.9    0.00236697          1  531.695            13  494675.000000        1
# sum       3.84931       2389   866158         26439            NaN      418
#
#                mvs      satoshi          time    vsize
# count         2391         2391  2.391000e+03     2391
# mean   0.000443844       160991  1.510869e+09  443.844
# std     0.00161938       616449  1.764781e+02  1619.38
# min       0.000134          226  1.510865e+09      134
# 25%       0.000225        49300  1.510869e+09      225
# 50%       0.000226       103183  1.510869e+09      226
# 75%       0.000338       114626  1.510869e+09      338
# max       0.044321  1.65234e+07  1.510869e+09    44321
# 0.1       0.000206        13559  1.510869e+09      206
# 0.2       0.000224        26400  1.510869e+09      224
# 0.3       0.000225        67800  1.510869e+09      225
# 0.4       0.000225        91476  1.510869e+09      225
# 0.5       0.000226       103183  1.510869e+09      226
# 0.6       0.000226       103203  1.510869e+09      226
# 0.7       0.000256       105299  1.510869e+09      256
# 0.8       0.000372       149818  1.510869e+09      372
# 0.9       0.000522       236697  1.510869e+09      522
# sum        1.06123    384930663           NaN  1061230

# %%
# Out:
# 'feerate_lfb60'
